# %% [markdown]
# Part 1

# %%
import intcode as intcode
import random 
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
f = open('input_d15.txt',"r")
line = f.readline()
l = [int(i.strip()) for i in line.split(',')]
l = {k: v for k,v in enumerate(l)}

# %%
def directions(input_d, point):
    if input_d==1:
        result = (point[0], point[1]+1)
    elif input_d==2:
        result = (point[0], point[1]-1)
    elif input_d==3:
        result = (point[0]-1, point[1])
    elif input_d==4:
        result = (point[0]+1, point[1])
    return result

# %%
output = 0
starting_point = (25,25)
i=0
relative_base = 0
cnt = 0
x = np.arange(50)
y = np.arange(50)
z = np.zeros([50,50])
points = [starting_point]
while output!=2:
    j = random.randint(1, 4)
    #print(starting_point)
    s = intcode.TEST3(l,j,i,relative_base)
    output = s[0][0]
    l = s[1]
    i = s[2]
    relative_base = s[3]
    if output == 0:
        starting_point = starting_point
        wall = directions(j, starting_point)
        z[wall[0], wall[1]] = 10
    else:
        starting_point = directions(j, starting_point)
        points.append(starting_point)
        #try:
        #    if points.index(starting_point):
        #        pass
        #except:
        #    points.append(starting_point)
        if output == 2:
            z[starting_point[0], starting_point[1]] = 20
    cnt = cnt+1

# %%
z[25,25]=30
plt.pcolor(x,y,z)

# %%
idx = 0
correct_path=[]
while idx<len(points):
    idx = max(loc for loc, val in enumerate(points) if val == points[idx])
    correct_path.append(points[idx])
    idx = idx+1

# %%
for i in correct_path:
    z[i[0],i[1]]=40

# %%
len(correct_path)-1
# Out:
# 236

# %% [markdown]
# Part 2

# %%
points2 = list(dict.fromkeys(points))

# %%
maximum = []
while len(points2)>0:
    idx = points.index(points2[0])
    path=[points2[0]]
    while idx<len(points):
        idx = max(loc for loc, val in enumerate(points) if val == points[idx])
        path.append(points[idx])
        idx = idx+1
    maximum.append(len(path))
    points2 = [x for x in points2 if x not in path]
    print(max(maximum)-1, len(points2))
# Out:
# 237 481
# 237 480
# 237 479
# 237 478
# 237 477
# 237 476
# 237 475
# 237 474
# 237 473
# 237 472
# 237 471
# 237 470
# 237 469
# 237 468
# 237 467
# 237 466
# 237 465
# 237 464
# 237 463
# 237 462
# 237 461
# 237 460
# 237 459
# 237 458
# 237 457
# 237 456
# 237 455
# 237 454
# 237 453
# 237 452
# 237 451
# 237 450
# 237 449
# 237 448
# 237 447
# 237 446
# 237 445
# 237 444
# 237 443
# 237 442
# 237 441
# 237 440
# 237 439
# 237 438
# 237 437
# 237 436
# 237 435
# 237 434
# 237 433
# 237 432
# 237 431
# 237 430
# 237 429
# 237 428
# 237 427
# 237 426
# 237 425
# 237 424
# 237 423
# 237 422
# 237 421
# 237 420
# 237 419
# 237 418
# 237 417
# 237 416
# 237 415
# 237 414
# 237 413
# 237 412
# 237 411
# 237 410
# 237 409
# 237 408
# 237 407
# 237 406
# 237 405
# 237 404
# 237 403
# 237 402
# 237 401
# 237 400
# 237 399
# 237 398
# 237 397
# 237 396
# 237 395
# 237 394
# 237 393
# 237 392
# 237 391
# 237 390
# 237 389
# 237 388
# 237 387
# 237 386
# 237 385
# 237 384
# 237 383
# 237 382
# 237 381
# 237 380
# 237 379
# 237 378
# 237 377
# 237 376
# 237 375
# 237 374
# 237 373
# 237 372
# 237 371
# 237 370
# 237 369
# 237 368
# 237 367
# 237 366
# 237 365
# 237 364
# 237 363
# 237 362
# 237 361
# 237 360
# 237 359
# 237 358
# 237 357
# 237 356
# 237 355
# 237 354
# 237 353
# 237 352
# 237 351
# 237 350
# 237 349
# 237 348
# 237 347
# 237 346
# 237 345
# 237 344
# 237 343
# 237 342
# 361 47
# 361 46
# 361 45
# 361 44
# 361 43
# 361 42
# 361 41
# 361 40
# 361 39
# 362 38
# 363 37
# 364 36
# 365 35
# 366 34
# 367 33
# 368 32
# 369 31
# 369 30
# 369 29
# 369 28
# 369 27
# 369 26
# 369 25
# 369 24
# 369 23
# 369 22
# 369 21
# 369 20
# 369 19
# 369 18
# 369 17
# 369 16
# 369 15
# 369 14
# 369 13
# 369 12
# 369 11
# 369 10
# 369 9
# 369 8
# 369 7
# 369 6
# 369 5
# 369 4
# 369 3
# 369 2
# 369 1
# 369 0

# %%
max(maximum)-2
# Out:
# 368

# %%
points2 = list(dict.fromkeys(points))

# %%
maximum = []
while len(points2)>0:
    idx = points.index(points2[math.floor(len(points2)/2)])
    path=[points2[0]]
    while idx<len(points):
        idx = max(loc for loc, val in enumerate(points) if val == points[idx])
        path.append(points[idx])
        idx = idx+1
    maximum.append(len(path)-2)
    points2 = [x for x in points2 if x not in path]
    print(max(maximum), len(points2))
# Out:
# 246 470
# 276 439
# 282 426
# 285 422
# 287 419
# 288 417
# 288 415
# 288 413
# 288 411
# 288 409
# 288 407
# 288 405
# 288 403
# 288 401
# 288 399
# 288 393
# 288 389
# 288 386
# 288 383
# 289 381
# 290 379
# 291 377
# 292 375
# 293 373
# 294 371
# 295 369
# 296 367
# 297 365
# 298 363
# 299 361
# 300 359
# 301 357
# 302 355
# 303 353
# 304 351
# 305 349
# 306 347
# 307 345
# 308 343
# 309 341
# 310 339
# 311 337
# 311 335
# 312 333
# 313 331
# 314 329
# 315 327
# 316 325
# 317 323
# 318 321
# 319 319
# 320 317
# 321 315
# 322 313
# 322 311
# 322 309
# 322 307
# 322 305
# 323 303
# 324 301
# 325 299
# 326 297
# 327 295
# 328 293
# 329 291
# 330 289
# 331 287
# 332 285
# 333 283
# 334 281
# 335 279
# 336 277
# 337 275
# 338 273
# 339 271
# 340 269
# 341 267
# 342 265
# 343 263
# 344 261
# 345 259
# 346 257
# 346 255
# 346 253
# 346 251
# 346 249
# 346 247
# 346 245
# 346 243
# 346 241
# 346 239
# 346 237
# 346 235
# 346 233
# 346 231
# 346 229
# 346 227
# 346 225
# 346 223
# 346 221
# 346 219
# 346 217
# 346 215
# 346 213
# 346 211
# 346 209
# 346 207
# 346 205
# 346 203
# 346 201
# 346 199
# 346 197
# 346 195
# 346 193
# 346 191
# 346 189
# 346 187
# 346 185
# 346 183
# 346 181
# 346 179
# 346 177
# 346 175
# 346 173
# 346 171
# 346 169
# 346 167
# 346 163
# 346 161
# 346 159
# 346 157
# 346 155
# 346 153
# 346 151
# 347 149
# 348 147
# 348 145
# 348 143
# 348 141
# 348 139
# 348 137
# 349 135
# 350 133
# 351 131
# 352 129
# 353 127
# 354 125
# 355 123
# 356 121
# 356 119
# 356 117
# 357 115
# 357 113
# 358 111
# 359 109
# 360 107
# 360 105
# 360 103
# 360 101
# 360 99
# 360 97
# 360 95
# 360 93
# 360 91
# 360 89
# 360 87
# 360 85
# 360 83
# 360 81
# 360 79
# 360 77
# 361 75
# 362 73
# 363 71
# 364 69
# 365 67
# 366 65
# 367 63
# 368 61
# 368 59
# 368 57
# 368 55
# 368 53
# 368 51
# 368 49
# 368 47
# 368 45
# 368 43
# 368 41
# 368 39
# 368 37
# 368 35
# 368 33
# 368 31
# 368 29
# 368 27
# 368 25
# 368 23
# 368 21
# 368 19
# 368 17
# 368 15
# 368 13
# 368 11
# 368 9
# 368 7
# 368 5
# 368 3
# 368 1
# 368 0
